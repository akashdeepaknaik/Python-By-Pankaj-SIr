# %% [markdown]
# # Day 2 : Language Fundamentals

# %% [markdown]
# ## Comments In Python
# ## 1. Single LIne Comment ( Starts with #)
# ## 2. Multiline Comment (Starts with ''' ''' or """ """)

# %%
#This is a Single line comment
print("Hello World")
# Out:
# Hello World

# %%
print("Hey") # This is also a single line comment
# Out:
# Hey

# %% [markdown]
# ## String

# %%
name="Akash"
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[1:4])
print(name*2)
print(len(name))
# Out:
# A
# k
# a
# s
# h
# kas
# AkashAkash
# 5

# %%
a="bhoomika"
b="akash"
print(a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a="bhoomika"
#       2 b="akash"
# ----> 3 print(a*b)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ## TypeCasting

# %% [markdown]
# ## 1. int() int is a function to convert anytype to int type

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int("123")
# Out:
# 123

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# ## 2. float() float is a function to convert anytype to float type

# %%
float(1)
# Out:
# 1.0

# %%
float(123.0)
# Out:
# 123.0

# %%
float("one")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 float("one")
#
# ValueError: could not convert string to float: 'one'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float("123.4")
# Out:
# 123.4

# %% [markdown]
# ## We can convert anytype to float except complex

# %% [markdown]
# ## 3. complex() : To convert anytype to complex type

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(12.3)
# Out:
# (12.3+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex("12")
# Out:
# (12+0j)

# %%
complex("12.4")
# Out:
# (12.4+0j)

# %%
complex("one")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 complex("one")
#
# ValueError: complex() arg is a malformed string

# %%
complex(12,0)
# Out:
# (12+0j)

# %% [markdown]
# ## 4. bool() : convert anytype to bool means True & False

# %%
bool(12)
# Out:
# True

# %%
bool(12.3)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(12+3)
# Out:
# True

# %%
bool(0.0123)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0+1j)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool("ten")
# Out:
# True

# %%
bool("Akash")
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool("")
# Out:
# False

# %% [markdown]
# ## 5. str() : convert any data type too string data type

# %%
str(10)
# Out:
# '10'

# %%
str('12.3')
# Out:
# '12.3'

# %%
str(12+2j)
# Out:
# '(12+2j)'

# %%
str(True)
# Out:
# 'True'
