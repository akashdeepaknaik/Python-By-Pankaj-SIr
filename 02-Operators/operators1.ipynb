# %% [markdown]
# # DAY 4 : OPERATORS LEC 01

# %% [markdown]
# # Arithmatic Operators

# %% [markdown]
# ## Example : +, - , * , / , // , % , **

# %%
a=10
b=20

# %%
print(a+b)
# Out:
# 30

# %%
print(a-b)
print(a*b)
# Out:
# -10
# 200

# %%
print(a/b) #/ operator always gives floating point arithmatic , returns float value
# Out:
# 0.5

# %%
# For floor value use //
print(a//b)
# Out:
# 0

# %% [markdown]
# ## There are two division operator in python
# ## Single / dicision gives value in float
# ## Double // division return floor value in int
# ## // it can perform both floor division as well as floating

# %%
20.0//6
# Out:
# 3.0

# %%
pi=3.14
radius=2
print(pi//radius)
# Out:
# 1.0

# %%
a=10
b=20
a//b
# Out:
# 0

# %% [markdown]
# ## Modulas operator

# %%
20%3
# Out:
# 2

# %%
## Modulas operator gives remainder

# %% [markdown]
# ## Power Operator **

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
2**4
# Out:
# 16

# %% [markdown]
# ## + Operator works on String as well but both operator must be of str type

# %%
a="Akash"
b="Naik"
a+b
# Out:
# 'AkashNaik'

# %% [markdown]
# "Akash"+10

# %% [markdown]
# ## We can also use string type with * Operator but in that case
# ## one argument must be int type and other must be str type

# %%
"Akash"*2
# Out:
# 'AkashAkash'

# %%
"Akash"*"Akash"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 "Akash"*"Akash"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
2.5*"Akash"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 2.5*"Akash"
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
a="3"+"2"
print(a)
print(type(a))
# Out:
# 32
# <class 'str'>

# %% [markdown]
# ## We cant multiply str to any float value only int

# %% [markdown]
# ## Relational Operator (< , > , <= , >=)

# %%
10<20
# Out:
# True

# %%
20>20
# Out:
# False

# %%
10<=10
# Out:
# True

# %% [markdown]
# ## Relational Operator Applicable to String also

# %%
a="Akash"
b="Naik" 
a<b  # A comes first before N in the disctionary So the answer is true
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a="Champa"
b="Champi" #in this case till champ is same it checks for a & i then gives the result
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %% [markdown]
# ## Logical Operator

# %% [markdown]
# ## and or not

# %% [markdown]
# ## Keep this line for and operator And hates false
# ## if both arguments are true then the result is true otherwise false

# %% [markdown]
# ## if first operand is false it will return first operand as answer

# %%
10 and 20 #true return 20
# Out:
# 20

# %% [markdown]
# ## or loves true

# %%
10 and "Akash" #true so result 2nd operand
# Out:
# 'Akash'

# %%
10.0+2+3j
# Out:
# (12+3j)

# %%
'Akash' and 'Naik'
# Out:
# 'Naik'

# %%
'' and 'Akash' #for empty string treated as false so 1st operand as answer
# Out:
# ''

# %% [markdown]
# ## for or operator if atleast one argument is true the result will be true , flase when both operands are false

# %%
10 or 20 #for or operator 1st operand is true then result will be 1st operand if 1st is false then the result will be 2nd operand
# Out:
# 10

# %%
0 or 20
# Out:
# 20

# %%
'Akash' or 'Naik'
# Out:
# 'Akash'

# %%
"" or "Akash"
# Out:
# 'Akash'

# %% [markdown]
# ## not operator

# %%
not 10
# Out:
# False

# %%
not 10.0
# Out:
# False

# %%
not "Akash"
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not ""
# Out:
# True

# %%
not 0+0j
# Out:
# True

# %% [markdown]
# ## bit-wise operator

# %% [markdown]
# ## bit-wise and operator

# %%
a=5 & 6

# %%
a
# Out:
# 4

# %%
True & True
# Out:
# True

# %%
10.3 ^ 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 10.3 ^ 4
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %% [markdown]
# ## bit-wise or operator

# %%
a=5|5

# %%
a
# Out:
# 5

# %% [markdown]
# ## bit-wise xor

# %%
a=5^6

# %%
a
# Out:
# 3
